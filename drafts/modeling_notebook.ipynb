# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn as sk
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

import warnings
warnings.filterwarnings('ignore')
pd.set_option('max_columns', 100)
pd.set_option('max_rows', 100)

from prepare_2 import wrangle_data, split_data

random_state = 42

# %%
df, sale_df, rent_df = wrangle_data()

# %%
target = 'newconstructionyn'
positive = 1

# %% [markdown]
# ## Prep for Modeling

# %% [markdown]
# ### Drop columns not used in modeling

# %%
cols_to_drop = [
                'address_id',               # unique identifier not useful
                'listingcontractdate',      # we'll use engineered date features instead
                'originallistprice',         # we'll use the scaled prices instead
                'originallistprice_persqft', # we'll use the scaled prices instead
                ]

df = df.drop(columns=cols_to_drop)

# %% [markdown]
# ### Encode categorical variables

# %%
def encode_data(df):
    '''
    This function takes in our dataset and encodes a given set of 
    categorical features using pandas one-hot encoder. It drops
    the original un-encoded columns and returns the df. 
    '''
    # categorical variables (that aren't already binary True/False)
    cols_to_encode = [
                      'propertytype', 
                      'propertysubtype', 
                     ]
    
    # create encoded column for each feature
    for col in cols_to_encode:
        dummy_df = pd.get_dummies(df[col],
                                  prefix=df[col].name,
                                  drop_first=True,
                                  dummy_na=False)
        # add encoded column to df
        df = pd.concat([df, dummy_df], axis=1)
        # drop original column
        df = df.drop(columns=col)
        
    return df

df = encode_data(df)

# %% [markdown]
# ### Turn boolean columns into 1/0

# %%
def convert_bools(df):
    '''
    This function takes in our dataset and converts all boolean columns to 1 or 0
    numeric datatypes, then returns the df.
    '''
    # identify boolean columns
    bools = [col for col in df.columns if df[col].dtype == 'bool']
    # convert to 1 or 0
    for col in bools:
        df[col] = df[col].map({True: 1, False: 0})
    return df

df = convert_bools(df)

# %% [markdown]
# ### Split the Data: Train & Test

# %%
train, test = split_data(df)

# %% [markdown]
# ### Scale quantitative variables

# %%
def scale_data(train, test, scaler_type=MinMaxScaler()):
    '''
    This takes in the train and test dataframes. 

    It then fits a scaler object to the train sample based on the given sample_type, applies that
    scaler to the trainand test samples, and appends the new scaled data to the 
    dataframes as additional columns with the prefix 'scaled_'. 

    train and test dataframes are returned, in that order. 
    '''
    # identify quantitative features to scale (that aren't already scaled)
    cols_to_scale = [
                     'lotsizearea', 
                     'bedroomstotal', 
                     'bathroomstotalinteger',
                     'bathroomsfull',
                     'bathroomshalf', 
                     'livingarea',
                     'stories', 
                     'yearbuilt',
                     'years_since_build', 
                     'garage_size', 
                     'central_cooling_units', 
                     'windowwall_cooling_units',
                     'listing_month',
                     'listing_dayofmonth', 
                     'listing_dayofweek'
                    ]
    
    # establish empty dataframes for storing scaled dataset
    train_scaled = pd.DataFrame(index=train.index)
    test_scaled = pd.DataFrame(index=test.index)
    
    # screate and fit the scaler
    scaler = scaler_type.fit(train[cols_to_scale])
    
    # adding scaled features to scaled dataframes
    train_scaled[cols_to_scale] = scaler.transform(train[cols_to_scale])
    test_scaled[cols_to_scale] = scaler.transform(test[cols_to_scale])
    
    # add 'scaled' prefix to columns
    for feature in cols_to_scale:
        train_scaled = train_scaled.rename(columns={feature: f'scaled_{feature}'})
        test_scaled = test_scaled.rename(columns={feature: f'scaled_{feature}'})
        
    # concat scaled feature columns to original train and test df's
    train = pd.concat([train, train_scaled], axis=1)
    test = pd.concat([test, test_scaled], axis=1)
    
    # drop the original columns
    train = train.drop(columns=cols_to_scale)
    test = test.drop(columns=cols_to_scale)

    return train, test

train, test = scale_data(train, test)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3002 entries, 1931 to 1859
# Data columns (total 66 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   garageyn                                3002 non-null   int64
#  1   newconstructionyn                       3002 non-null   int64
#  2   listed_on_weekend                       3002 non-null   int64
#  3   previously_listed                       3002 non-null   int64
#  4   built_last_two_years                    3002 non-null   int64
#  5   parkingfeatures_attached                3002 non-null   int64
#  6   parkingfeatures_detached                3002 non-null   int64
#  7   parkingfeatures_oversized               3002 non-null   int64
#  8   parkingfeatures_converted               3002 non-null   int64
#  9   parkingfeatures_sideentry               3002 non-null   int64
#  10  parkingfeatures_rearentry               3002 non-null   int64
#  11  parkingfeatures_tandem                  3002 non-null   int64
#  12  parkingfeatures_golfcart                3002 non-null   int64
#  13  heating_central                         3002 non-null   int64
#  14  heating_naturalgas                      3002 non-null   int64
#  15  heating_electric                        3002 non-null   int64
#  16  heating_2units                          3002 non-null   int64
#  17  heating_heatpump                        3002 non-null   int64
#  18  heating_1unit                           3002 non-null   int64
#  19  heating_zoned                           3002 non-null   int64
#  20  heating_other                           3002 non-null   int64
#  21  heating_floorfurnace                    3002 non-null   int64
#  22  heating_solar                           3002 non-null   int64
#  23  heating_propaneowned                    3002 non-null   int64
#  24  heating_none                            3002 non-null   int64
#  25  heating_windowunit                      3002 non-null   int64
#  26  cooling_central                         3002 non-null   int64
#  27  cooling_windowwall                      3002 non-null   int64
#  28  cooling_heatpump                        3002 non-null   int64
#  29  cooling_zoned                           3002 non-null   int64
#  30  archstyle_traditional                   3002 non-null   int64
#  31  archstyle_contemporary                  3002 non-null   int64
#  32  archstyle_splitlevel                    3002 non-null   int64
#  33  archstyle_ranch                         3002 non-null   int64
#  34  archstyle_texashillcountry              3002 non-null   int64
#  35  archstyle_craftsman                     3002 non-null   int64
#  36  archstyle_other                         3002 non-null   int64
#  37  archstyle_colonial                      3002 non-null   int64
#  38  archstyle_spanish                       3002 non-null   int64
#  39  archstyle_manufacturedhome-singlewide   3002 non-null   int64
#  40  archstyle_a-frame                       3002 non-null   int64
#  41  lotsizearea_listed_negative             3002 non-null   int64
#  42  lotsizearea_small                       3002 non-null   int64
#  43  originallistprice_scaled                3002 non-null   float64
#  44  originallistprice_persqft_scaled        3002 non-null   float64
#  45  propertytype_Residential Rental         3002 non-null   uint8
#  46  propertysubtype_Condominium             3002 non-null   uint8
#  47  propertysubtype_Duplex                  3002 non-null   uint8
#  48  propertysubtype_Manufactured Home       3002 non-null   uint8
#  49  propertysubtype_Single Family Detached  3002 non-null   uint8
#  50  propertysubtype_Townhouse               3002 non-null   uint8
#  51  scaled_lotsizearea                      3002 non-null   float64
#  52  scaled_bedroomstotal                    3002 non-null   float64
#  53  scaled_bathroomstotalinteger            3002 non-null   float64
#  54  scaled_bathroomsfull                    3002 non-null   float64
#  55  scaled_bathroomshalf                    3002 non-null   float64
#  56  scaled_livingarea                       3002 non-null   float64
#  57  scaled_stories                          3002 non-null   float64
#  58  scaled_yearbuilt                        3002 non-null   float64
#  59  scaled_years_since_build                3002 non-null   float64
#  60  scaled_garage_size                      3002 non-null   float64
#  61  scaled_central_cooling_units            3002 non-null   float64
#  62  scaled_windowwall_cooling_units         3002 non-null   float64
#  63  scaled_listing_month                    3002 non-null   float64
#  64  scaled_listing_dayofmonth               3002 non-null   float64
#  65  scaled_listing_dayofweek                3002 non-null   float64
# dtypes: float64(17), int64(43), uint8(6)
# memory usage: 1.4 MB

# %% [markdown]
# ## Baseline Predictions

# %% [markdown]
# #### A simple baseline - predicting the most common class

# %% [markdown]
# Since the majority of properties are not new construction, our simplest baseline would be to predict 0 for each property.

# %%
def run_baseline_1(train,
                   target,
                   positive,
                   model_number,
                   model_info,
                   model_results):
    '''
    This function takes in the train sample, the target variable label, the positive condition label,
    an initialized model_number variable, as well as model_info and model_results dataframes dataframes that will be used for 
    storing information about the models. It then performs the operations necessary for making baseline predictions
    on our dataset, and stores information about our baseline model in the model_info and model_results dataframes. 
    (i.e. predicts the most common class)
    The model_number, model_info, and model_results variables are returned (in that order). 
    '''

    # separate each sample into x (features) and y (target)
    x_train = train.drop(columns=target)
    y_train = train[target]


    # store baseline metrics

    # identify model number
    model_number = 'baseline_1'
    #identify model type
    model_type = 'baseline_1'

    # store info about the model

    # create a dictionary containing model number and model type
    dct = {'model_number': model_number,
           'model_type': model_type}
    # append that dictionary to the model_info dataframe
    model_info = model_info.append(dct, ignore_index=True)

    # establish baseline predictions for train sample
    y_pred = pd.Series([train[target].mode()[0]]).repeat(len(train))

    # get metrics

    # create dictionaries for each metric type for the train sample and append those dictionaries to the model_results dataframe
    dct = {'model_number': model_number, 
           'metric_type': 'accuracy',
           'score': sk.metrics.accuracy_score(y_train, y_pred)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'precision',
           'score': sk.metrics.precision_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'recall',
           'score': sk.metrics.recall_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'f1_score',
           'score': sk.metrics.f1_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    # set the model number to from 'baseline' to 0 
    model_number = 0
    
    return model_number, model_info, model_results

# %%
# setting up the infrastructure to store information about our models
model_number = 0
model_info = pd.DataFrame()
model_results = pd.DataFrame()

# %%
model_number, model_info, model_results = run_baseline_1(train, target, positive,
                                                         model_number, model_info, model_results)

# %% [markdown]
# #### An alternative baseline - predicting the positive class

# %% [markdown]
# However, if our goal is to maximize recall, i.e. identify as many new construction as possible, a more reasonable baseline might be to treat all properties as if they are new construction (i.e. always predict 1).

# %%
def run_baseline_2(train,
                   target,
                   positive,
                   model_number,
                   model_info,
                   model_results):
    '''
    This function takes in the train sample, the target variable label, the positive condition label,
    an initialized model_number variable, as well as model_info and model_results dataframes dataframes that will be used for 
    storing information about the models. It then performs the operations necessary for making baseline predictions
    on our dataset, and stores information about our baseline model in the model_info and model_results dataframes. 
    The model_number, model_info, and model_results variables are returned (in that order). 
    
    For this alternative baseline, we will maximize recall by always predicting 1.
    '''

    # separate each sample into x (features) and y (target)
    x_train = train.drop(columns=target)
    y_train = train[target]

    # store baseline metrics

    # identify model number
    model_number = 'baseline_2'
    #identify model type
    model_type = 'baseline_2'

    # store info about the model

    # create a dictionary containing model number and model type
    dct = {'model_number': model_number,
           'model_type': model_type}
    # append that dictionary to the model_info dataframe
    model_info = model_info.append(dct, ignore_index=True)

    # establish baseline predictions for train sample
    y_pred = pd.Series(1).repeat(len(train))

    # get metrics

    # create dictionaries for each metric type for the train sample and append those dictionaries to the model_results dataframe
    dct = {'model_number': model_number, 
           'metric_type': 'accuracy',
           'score': sk.metrics.accuracy_score(y_train, y_pred)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'precision',
           'score': sk.metrics.precision_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'recall',
           'score': sk.metrics.recall_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'f1_score',
           'score': sk.metrics.f1_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    # set the model number to from 'baseline' to 0 
    model_number = 0
    
    return model_number, model_info, model_results

# %%
model_number, model_info, model_results = run_baseline_2(train, target, positive,
                                                         model_number, model_info, model_results)

# %%
model_results
# Out:
#   model_number metric_type     score
# 0   baseline_1    accuracy  0.792472
# 1   baseline_1   precision  0.000000
# 2   baseline_1      recall  0.000000
# 3   baseline_1    f1_score  0.000000
# 4   baseline_2    accuracy  0.207528
# 5   baseline_2   precision  0.207528
# 6   baseline_2      recall  1.000000
# 7   baseline_2    f1_score  0.343724

# %% [markdown]
# ## An Intuitive Baseline Model

# %% [markdown]
# #### Using the most intuitive way of determining new construction as a more effective baseline

# %% [markdown]
# Exploration found that our most reliable feature is whether the build year of the property is within two calendar years of the listing date. This is also very intuitive - any reasonable person looking at a listing and trying to guess whether it was new construction would look for a recent build year. If our eventual model cannot predict more reliably than that, it will not be of much use.

# %%
def run_model_1(train,
                target,
                positive,
                model_number,
                model_info,
                model_results):
    '''
    This function predicts whether a property is new construction based only on whether the build year is within
    two calendar years of the listing. This will create a more effective and useful baseline for which to compare
    future, more complex models. 
    
    This function takes in the train sample, the target variable label, the positive condition label,
    as well as the model_number variable and model_info and model_results dataframes. It then updates and returns
    the model_number, model_info, and model_results variables after creating and storing info about the model 
    described above.
    '''

    # separate each sample into x (features) and y (target)
    x_train = train.drop(columns=target)
    y_train = train[target]

    # identify model number
    model_number +=1
    #identify model type
    model_type = 'simple build year'

    # store info about the model

    # create a dictionary containing model number and model type
    dct = {'model_number': model_number,
           'model_type': model_type}
    # append that dictionary to the model_info dataframe
    model_info = model_info.append(dct, ignore_index=True)

    # establish predictions for train sample
    y_pred = train.built_last_two_years

    # get metrics

    # create dictionaries for each metric type for the train sample and append those dictionaries to the model_results dataframe
    dct = {'model_number': model_number, 
           'metric_type': 'accuracy',
           'score': sk.metrics.accuracy_score(y_train, y_pred)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'precision',
           'score': sk.metrics.precision_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'recall',
           'score': sk.metrics.recall_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)

    dct = {'model_number': model_number, 
           'metric_type': 'f1_score',
           'score': sk.metrics.f1_score(y_train, y_pred, pos_label=positive)}
    model_results = model_results.append(dct, ignore_index=True)
    
    return model_number, model_info, model_results

# %%
model_number, model_info, model_results = run_model_1(train, target, positive,
                                                      model_number, model_info, model_results)

# %%
def display_model_results(model_results):
    '''
    This function takes in the model_results dataframe. This is a dataframe in tidy data format 
    containing the following information for each model created in the project:
    - model number
    - metric type (accuracy, precision, recall, f1 score)
    - sample type (train, validate)
    - score (the score for the given metric and sample types)
    The function returns a pivot table of those values for easy comparison of models, metrics, and samples. 
    '''
    # create a pivot table of the model_results dataframe
    # establish columns as the model_number, with index as metric_type, and values as score
    # the aggfunc uses a lambda to return each individual score without any aggregation applied
    return model_results.pivot_table(columns='model_number', 
                                     index=('metric_type'), 
                                     values='score',
                                     aggfunc=lambda x: x)

# %%
model_results
# Out:
#    model_number metric_type     score
# 0    baseline_1    accuracy  0.792472
# 1    baseline_1   precision  0.000000
# 2    baseline_1      recall  0.000000
# 3    baseline_1    f1_score  0.000000
# 4    baseline_2    accuracy  0.207528
# 5    baseline_2   precision  0.207528
# 6    baseline_2      recall  1.000000
# 7    baseline_2    f1_score  0.343724
# 8             1    accuracy  0.974017
# 9             1   precision  0.901325
# 10            1      recall  0.982343
# 11            1    f1_score  0.940092

# %%
display_model_results(model_results).T
# Out:
# metric_type   accuracy  f1_score  precision    recall
# model_number
# 1             0.974017  0.940092   0.901325  0.982343
# baseline_1    0.792472  0.000000   0.000000  0.000000
# baseline_2    0.207528  0.343724   0.207528  1.000000

# %% [markdown]
# ## ML Modeling

# %% [markdown]
# Now I will do some simple machine learning modeling to see if we can improve upon the performance of our basic build-year-only model.

# %%
# first feature set uses only those which appeared to be meaningful during exploration
features1 = ['built_last_two_years',
             'previously_listed',
             'scaled_stories',
             'cooling_windowwall',
             'originallistprice_persqft_scaled'
            ]

feature_sets = [features1]

# %% [markdown]
# ### Decision Tree

# %%
def decision_tree(train,
                  target, 
                  positive,
                  feature_sets,
                  model_number, 
                  model_info, 
                  model_results):

    # establish hyperparameter ranges
    min_max_depth = 3
    max_max_depth = 10

    # establish loops based on feature sets and hyperparameter ranges
    count = 1
    for features in feature_sets: 
        for max_depth in range(min_max_depth, max_max_depth + 1):

            # cache completed model info / model results
            model_info.to_csv('model_info.csv')
            model_results.to_csv('model_results.csv')

            ##################
            ### Model Info ###
            ##################

            # create a new model number by adding 1 to the previous model number
            model_number += 1
            # establish the model type
            model_type = 'decision tree'

            # store info about the model

            # create a dictionary containing the features and hyperparamters used in this model instance
            dct = {'model_number': model_number,
                   'model_type': model_type,
                   'features': features,
                   'max_depth': max_depth}
            # append that dictionary to the model_info dataframe
            model_info = model_info.append(dct, ignore_index=True)

            ################
            ### Modeling ###
            ################

            # separate each sample into x (features) and y (target)
            x_train = train[features]
            y_train= train[target]


            # create the classifer

            # establish a decision tree classifier with the given max depth
            # set a random state for repoduceability
            clf = DecisionTreeClassifier(max_depth=max_depth, random_state=random_state)

            # fit the classifier to the training data
            clf = clf.fit(x_train, y_train)

            #####################
            ### Model Results ###
            #####################

            # create prediction results for the model's performance on the train sample
            y_pred = clf.predict(x_train)

            # get metrics

            # create dictionaries for each metric type for the train sample and append those dictionaries to the model_results dataframe
            dct = {'model_number': model_number, 
                   'metric_type': 'accuracy',
                   'score': sk.metrics.accuracy_score(y_train, y_pred)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'precision',
                   'score': sk.metrics.precision_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'recall',
                   'score': sk.metrics.recall_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'f1_score',
                   'score': sk.metrics.f1_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)
            
    return model_number, model_info, model_results

# %%
model_number, model_info, model_results = decision_tree(train, target, positive, feature_sets,
                                                        model_number, model_info, model_results)

# %%
model_info
# Out:
#    model_number         model_type  \
# 0    baseline_1         baseline_1
# 1    baseline_2         baseline_2
# 2             1  simple build year
# 3             2      decision tree
# 4             3      decision tree
# 5             4      decision tree
# 6             5      decision tree
# 7             6      decision tree
# 8             7      decision tree
# 9             8      decision tree
# 10            9      decision tree
#
#                                              features  max_depth
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3   [built_last_two_years, previously_listed, scal...        3.0
# 4   [built_last_two_years, previously_listed, scal...        4.0
# 5   [built_last_two_years, previously_listed, scal...        5.0
# 6   [built_last_two_years, previously_listed, scal...        6.0
# 7   [built_last_two_years, previously_listed, scal...        7.0
# 8   [built_last_two_years, previously_listed, scal...        8.0
# 9   [built_last_two_years, previously_listed, scal...        9.0
# 10  [built_last_two_years, previously_listed, scal...       10.0

# %%
display_model_results(model_results)
# Out:
# model_number         1         2         3         4         5         6  \
# metric_type
# accuracy      0.974017  0.975350  0.975683  0.976682  0.977015  0.977015
# f1_score      0.940092  0.942724  0.943542  0.945820  0.946636  0.946636
# precision     0.901325  0.910314  0.910448  0.913303  0.913433  0.913433
# recall        0.982343  0.977528  0.979133  0.980738  0.982343  0.982343
#
# model_number         7         8         9  baseline_1  baseline_2
# metric_type
# accuracy      0.977015  0.977015  0.978015    0.792472    0.207528
# f1_score      0.946636  0.946636  0.948758    0.000000    0.343724
# precision     0.913433  0.913433  0.918797    0.000000    0.207528
# recall        0.982343  0.982343  0.980738    0.000000    1.000000

# %% [markdown]
# ### Decision Tree - RFE

# %% [markdown]
# Next we'll attempt to use automated feature selection in the Decision Tree model to determine the most important features.

# %%
def rfe_decision_tree(train,
                      target, 
                      positive, 
                      model_number, 
                      model_info, 
                      model_results):

    # all available features
    all_features = [col for col in train.columns if col != target]

    # separate each sample into x (features) and y (target) - for RFE
    x_train_rfe = train[all_features]
    y_train_rfe = train[target]

    # establish hyperparameter ranges
    min_n_features = 2
    max_n_features = 12

    min_max_depth = 3
    max_max_depth = 10

    # establish loops based on hyperparameter ranges
    count = 1
    for n_features in range(min_n_features, max_n_features + 1):
        for max_depth in range(min_max_depth, max_max_depth + 1):

            # cache completed model info / model results
            model_info.to_csv('model_info.csv')
            model_results.to_csv('model_results.csv')

            #####################################
            ### Recursive Feature Elimination ###
            #####################################

            # establish a decision tree classifier
            clf = DecisionTreeClassifier(max_depth=max_depth, random_state=random_state)

            # create the rfe object
            rfe = RFE(clf, n_features_to_select=n_features)

            # fit the data using RFE
            rfe.fit(x_train_rfe, y_train_rfe)

            # get list of the column names for the selected features
            features = x_train_rfe.iloc[:,rfe.support_].columns.tolist()

            ##################
            ### Model Info ###
            ##################

            # create a new model number by adding 1 to the previous model number
            model_number += 1
            # establish the model type
            model_type = 'decision tree'

            # store info about the model

            # create a dictionary containing the features and hyperparamters used in this model instance
            dct = {'model_number': model_number,
                   'model_type': model_type,
                   'features': features,
                   'max_depth': max_depth}
            # append that dictionary to the model_info dataframe
            model_info = model_info.append(dct, ignore_index=True)

            ################
            ### Modeling ###
            ################

            # separate each sample into x (features) and y (target)
            x_train = train[features]
            y_train = train[target]

            # create the classifer

            # establish a decision tree classifier with the given max depth
            # set a random state for repoduceability
            clf = DecisionTreeClassifier(max_depth=max_depth, random_state=42)

            # fit the classifier to the training data
            clf = clf.fit(x_train, y_train)

            #####################
            ### Model Results ###
            #####################

            ####### train #######

            # create prediction results for the model's performance on the train sample
            y_pred = clf.predict(x_train)

            # get metrics

            # create dictionaries for each metric type for the train sample and append those dictionaries to the model_results dataframe
            dct = {'model_number': model_number, 
                   'metric_type': 'accuracy',
                   'score': sk.metrics.accuracy_score(y_train, y_pred)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'precision',
                   'score': sk.metrics.precision_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'recall',
                   'score': sk.metrics.recall_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)

            dct = {'model_number': model_number, 
                   'metric_type': 'f1_score',
                   'score': sk.metrics.f1_score(y_train, y_pred, pos_label=positive)}
            model_results = model_results.append(dct, ignore_index=True)

            
    return model_number, model_info, model_results

# %%
model_number,  model_info, model_results = rfe_decision_tree(train, target, positive, 
                                                             model_number, model_info, model_results)

# %%
model_info
# Out:
#    model_number         model_type  \
# 0    baseline_1         baseline_1
# 1    baseline_2         baseline_2
# 2             1  simple build year
# 3             2      decision tree
# 4             3      decision tree
# 5             4      decision tree
# 6             5      decision tree
# 7             6      decision tree
# 8             7      decision tree
# 9             8      decision tree
# 10            9      decision tree
# 11           10      decision tree
# 12           11      decision tree
# 13           12      decision tree
# 14           13      decision tree
# 15           14      decision tree
# 16           15      decision tree
# 17           16      decision tree
# 18           17      decision tree
# 19           18      decision tree
# 20           19      decision tree
# 21           20      decision tree
# 22           21      decision tree
# 23           22      decision tree
# 24           23      decision tree
# 25           24      decision tree
# 26           25      decision tree
# 27           26      decision tree
# 28           27      decision tree
# 29           28      decision tree
# 30           29      decision tree
# 31           30      decision tree
# 32           31      decision tree
# 33           32      decision tree
# 34           33      decision tree
# 35           34      decision tree
# 36           35      decision tree
# 37           36      decision tree
# 38           37      decision tree
# 39           38      decision tree
# 40           39      decision tree
# 41           40      decision tree
# 42           41      decision tree
# 43           42      decision tree
# 44           43      decision tree
# 45           44      decision tree
# 46           45      decision tree
# 47           46      decision tree
# 48           47      decision tree
# 49           48      decision tree
# 50           49      decision tree
# 51           50      decision tree
# 52           51      decision tree
# 53           52      decision tree
# 54           53      decision tree
# 55           54      decision tree
# 56           55      decision tree
# 57           56      decision tree
# 58           57      decision tree
# 59           58      decision tree
# 60           59      decision tree
# 61           60      decision tree
# 62           61      decision tree
# 63           62      decision tree
# 64           63      decision tree
# 65           64      decision tree
# 66           65      decision tree
# 67           66      decision tree
# 68           67      decision tree
# 69           68      decision tree
# 70           69      decision tree
# 71           70      decision tree
# 72           71      decision tree
# 73           72      decision tree
# 74           73      decision tree
# 75           74      decision tree
# 76           75      decision tree
# 77           76      decision tree
# 78           77      decision tree
# 79           78      decision tree
# 80           79      decision tree
# 81           80      decision tree
# 82           81      decision tree
# 83           82      decision tree
# 84           83      decision tree
# 85           84      decision tree
# 86           85      decision tree
# 87           86      decision tree
# 88           87      decision tree
# 89           88      decision tree
# 90           89      decision tree
# 91           90      decision tree
# 92           91      decision tree
# 93           92      decision tree
# 94           93      decision tree
# 95           94      decision tree
# 96           95      decision tree
# 97           96      decision tree
# 98           97      decision tree
#
#                                              features  max_depth
# 0                                                 NaN        NaN
# 1                                                 NaN        NaN
# 2                                                 NaN        NaN
# 3   [built_last_two_years, previously_listed, scal...        3.0
# 4   [built_last_two_years, previously_listed, scal...        4.0
# 5   [built_last_two_years, previously_listed, scal...        5.0
# 6   [built_last_two_years, previously_listed, scal...        6.0
# 7   [built_last_two_years, previously_listed, scal...        7.0
# 8   [built_last_two_years, previously_listed, scal...        8.0
# 9   [built_last_two_years, previously_listed, scal...        9.0
# 10  [built_last_two_years, previously_listed, scal...       10.0
# 11       [scaled_yearbuilt, scaled_years_since_build]        3.0
# 12     [scaled_lotsizearea, scaled_years_since_build]        4.0
# 13     [scaled_lotsizearea, scaled_years_since_build]        5.0
# 14      [scaled_livingarea, scaled_years_since_build]        6.0
# 15  [originallistprice_scaled, scaled_years_since_...        7.0
# 16  [originallistprice_scaled, scaled_years_since_...        8.0
# 17  [originallistprice_scaled, scaled_years_since_...        9.0
# 18  [originallistprice_scaled, scaled_years_since_...       10.0
# 19  [scaled_lotsizearea, scaled_yearbuilt, scaled_...        3.0
# 20  [scaled_lotsizearea, scaled_yearbuilt, scaled_...        4.0
# 21  [scaled_lotsizearea, scaled_yearbuilt, scaled_...        5.0
# 22  [scaled_livingarea, scaled_yearbuilt, scaled_y...        6.0
# 23  [originallistprice_scaled, scaled_livingarea, ...        7.0
# 24  [originallistprice_scaled, scaled_livingarea, ...        8.0
# 25  [originallistprice_scaled, scaled_livingarea, ...        9.0
# 26  [originallistprice_scaled, scaled_livingarea, ...       10.0
# 27  [propertytype_Residential Rental, scaled_lotsi...        3.0
# 28  [propertytype_Residential Rental, scaled_lotsi...        4.0
# 29  [scaled_lotsizearea, scaled_livingarea, scaled...        5.0
# 30  [scaled_lotsizearea, scaled_livingarea, scaled...        6.0
# 31  [originallistprice_scaled, scaled_livingarea, ...        7.0
# 32  [originallistprice_scaled, scaled_livingarea, ...        8.0
# 33  [originallistprice_scaled, scaled_livingarea, ...        9.0
# 34  [originallistprice_scaled, scaled_livingarea, ...       10.0
# 35  [archstyle_ranch, propertytype_Residential Ren...        3.0
# 36  [propertytype_Residential Rental, scaled_lotsi...        4.0
# 37  [propertytype_Residential Rental, scaled_lotsi...        5.0
# 38  [propertytype_Residential Rental, scaled_lotsi...        6.0
# 39  [originallistprice_scaled, scaled_lotsizearea,...        7.0
# 40  [originallistprice_scaled, scaled_lotsizearea,...        8.0
# 41  [originallistprice_scaled, scaled_lotsizearea,...        9.0
# 42  [originallistprice_scaled, scaled_lotsizearea,...       10.0
# 43  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 44  [propertytype_Residential Rental, scaled_lotsi...        4.0
# 45  [propertytype_Residential Rental, scaled_lotsi...        5.0
# 46  [propertytype_Residential Rental, scaled_lotsi...        6.0
# 47  [originallistprice_scaled, propertytype_Reside...        7.0
# 48  [originallistprice_scaled, scaled_lotsizearea,...        8.0
# 49  [originallistprice_scaled, scaled_lotsizearea,...        9.0
# 50  [originallistprice_scaled, scaled_lotsizearea,...       10.0
# 51  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 52  [archstyle_ranch, propertytype_Residential Ren...        4.0
# 53  [archstyle_ranch, propertytype_Residential Ren...        5.0
# 54  [propertytype_Residential Rental, scaled_lotsi...        6.0
# 55  [originallistprice_scaled, propertytype_Reside...        7.0
# 56  [originallistprice_scaled, scaled_lotsizearea,...        8.0
# 57  [originallistprice_scaled, scaled_lotsizearea,...        9.0
# 58  [originallistprice_scaled, scaled_lotsizearea,...       10.0
# 59  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 60  [heating_zoned, archstyle_ranch, propertytype_...        4.0
# 61  [archstyle_ranch, originallistprice_scaled, pr...        5.0
# 62  [archstyle_ranch, propertytype_Residential Ren...        6.0
# 63  [originallistprice_scaled, propertytype_Reside...        7.0
# 64  [originallistprice_scaled, propertytype_Reside...        8.0
# 65  [originallistprice_scaled, propertytype_Reside...        9.0
# 66  [originallistprice_scaled, propertytype_Reside...       10.0
# 67  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 68  [parkingfeatures_oversized, heating_zoned, arc...        4.0
# 69  [parkingfeatures_oversized, archstyle_ranch, o...        5.0
# 70  [archstyle_ranch, originallistprice_scaled, pr...        6.0
# 71  [archstyle_ranch, originallistprice_scaled, pr...        7.0
# 72  [parkingfeatures_attached, originallistprice_s...        8.0
# 73  [parkingfeatures_attached, originallistprice_s...        9.0
# 74  [parkingfeatures_attached, originallistprice_s...       10.0
# 75  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 76  [parkingfeatures_oversized, heating_zoned, arc...        4.0
# 77  [parkingfeatures_oversized, archstyle_ranch, o...        5.0
# 78  [parkingfeatures_oversized, archstyle_ranch, o...        6.0
# 79  [parkingfeatures_oversized, archstyle_ranch, o...        7.0
# 80  [parkingfeatures_attached, archstyle_ranch, or...        8.0
# 81  [parkingfeatures_attached, archstyle_ranch, or...        9.0
# 82  [parkingfeatures_attached, archstyle_ranch, or...       10.0
# 83  [parkingfeatures_oversized, archstyle_ranch, p...        3.0
# 84  [parkingfeatures_oversized, heating_zoned, arc...        4.0
# 85  [previously_listed, parkingfeatures_oversized,...        5.0
# 86  [previously_listed, parkingfeatures_oversized,...        6.0
# 87  [previously_listed, parkingfeatures_oversized,...        7.0
# 88  [parkingfeatures_attached, heating_1unit, arch...        8.0
# 89  [parkingfeatures_attached, heating_1unit, arch...        9.0
# 90  [parkingfeatures_attached, heating_1unit, arch...       10.0
# 91  [parkingfeatures_oversized, heating_naturalgas...        3.0
# 92  [parkingfeatures_oversized, heating_zoned, arc...        4.0
# 93  [previously_listed, parkingfeatures_oversized,...        5.0
# 94  [previously_listed, parkingfeatures_oversized,...        6.0
# 95  [previously_listed, parkingfeatures_oversized,...        7.0
# 96  [parkingfeatures_attached, parkingfeatures_ove...        8.0
# 97  [parkingfeatures_attached, parkingfeatures_ove...        9.0
# 98  [parkingfeatures_attached, parkingfeatures_ove...       10.0

# %%
display_model_results(model_results)
# Out:
# model_number         1         2         3         4         5         6  \
# metric_type
# accuracy      0.974017  0.975350  0.975683  0.976682  0.977015  0.977015
# f1_score      0.940092  0.942724  0.943542  0.945820  0.946636  0.946636
# precision     0.901325  0.910314  0.910448  0.913303  0.913433  0.913433
# recall        0.982343  0.977528  0.979133  0.980738  0.982343  0.982343
#
# model_number         7         8         9        10        11        12  \
# metric_type
# accuracy      0.977015  0.977015  0.978015  0.988008  0.990007  0.990007
# f1_score      0.946636  0.946636  0.948758  0.970636  0.975610  0.975610
# precision     0.913433  0.913433  0.918797  0.986733  0.988468  0.988468
# recall        0.982343  0.982343  0.980738  0.955056  0.963082  0.963082
#
# model_number        13        14        15        16        17        18  \
# metric_type
# accuracy      0.990673  0.994337  0.995336  0.996336  0.997668  0.989674
# f1_score      0.977199  0.986235  0.988673  0.991108  0.994350  0.974899
# precision     0.991736  0.995098  0.996737  0.998371  1.000000  0.983660
# recall        0.963082  0.977528  0.980738  0.983949  0.988764  0.966292
#
# model_number        19        20        21        22        23        24  \
# metric_type
# accuracy      0.990007  0.990340  0.990673  0.996336  0.996669  0.999334
# f1_score      0.975728  0.976556  0.977199  0.991150  0.991935  0.998395
# precision     0.983687  0.983713  0.991736  0.993548  0.996759  0.998395
# recall        0.967897  0.969502  0.963082  0.988764  0.987159  0.998395
#
# model_number        25        26        27        28        29        30  \
# metric_type
# accuracy      0.999667  0.989674  0.990340  0.991006  0.992672  0.994337
# f1_score      0.999197  0.975020  0.976594  0.978102  0.982172  0.986279
# precision     1.000000  0.978964  0.982143  0.988525  0.991817  0.991883
# recall        0.998395  0.971108  0.971108  0.967897  0.972713  0.980738
#
# model_number        31        32        33        34        35        36  \
# metric_type
# accuracy      0.996003  0.997002  0.998001  0.989674  0.991006  0.991672
# f1_score      0.990307  0.992748  0.995169  0.975020  0.978208  0.979790
# precision     0.996748  0.996764  0.998384  0.978964  0.983766  0.986971
# recall        0.983949  0.988764  0.991974  0.971108  0.972713  0.972713
#
# model_number        37        38        39        40        41        42  \
# metric_type
# accuracy      0.992672  0.993338  0.995670  0.996003  0.997335  0.989674
# f1_score      0.982172  0.983819  0.989508  0.990307  0.993548  0.975020
# precision     0.991817  0.991843  0.995130  0.996748  0.998379  0.978964
# recall        0.972713  0.975923  0.983949  0.983949  0.988764  0.971108
#
# model_number        43        44        45        46        47        48  \
# metric_type
# accuracy      0.991006  0.992338  0.993671  0.994337  0.995670  0.996336
# f1_score      0.978278  0.981437  0.984615  0.986257  0.989508  0.991122
# precision     0.980645  0.987013  0.993464  0.993485  0.995130  0.996753
# recall        0.975923  0.975923  0.975923  0.979133  0.983949  0.985554
#
# model_number        49        50        51        52        53        54  \
# metric_type
# accuracy      0.997668  0.989674  0.991339  0.992672  0.993338  0.994670
# f1_score      0.994350  0.975020  0.979066  0.982229  0.983793  0.987076
# precision     1.000000  0.978964  0.982229  0.988618  0.993453  0.993496
# recall        0.988764  0.971108  0.975923  0.975923  0.974318  0.980738
#
# model_number        55        56        57        58        59        60  \
# metric_type
# accuracy      0.995670  0.996336  0.997668  0.989674  0.991006  0.992672
# f1_score      0.989508  0.991122  0.994350  0.975020  0.978278  0.982229
# precision     0.995130  0.996753  1.000000  0.978964  0.980645  0.988618
# recall        0.983949  0.985554  0.988764  0.971108  0.975923  0.975923
#
# model_number        61        62        63        64        65        66  \
# metric_type
# accuracy      0.993671  0.995003  0.995670  0.996336  0.997668  0.989674
# f1_score      0.984615  0.987893  0.989508  0.991122  0.994350  0.975020
# precision     0.993464  0.993506  0.995130  0.996753  1.000000  0.978964
# recall        0.975923  0.982343  0.983949  0.985554  0.988764  0.971108
#
# model_number        67        68        69        70        71        72  \
# metric_type
# accuracy      0.991672  0.993338  0.994337  0.995003  0.995670  0.996336
# f1_score      0.979855  0.983819  0.986301  0.987874  0.989508  0.991108
# precision     0.983819  0.991843  0.990291  0.995114  0.995130  0.998371
# recall        0.975923  0.975923  0.982343  0.980738  0.983949  0.983949
#
# model_number        73        74        75        76        77        78  \
# metric_type
# accuracy      0.998001  0.989674  0.991672  0.993338  0.994670  0.995336
# f1_score      0.995161  0.975020  0.979855  0.983819  0.987097  0.988691
# precision     1.000000  0.978964  0.983819  0.991843  0.991896  0.995122
# recall        0.990369  0.971108  0.975923  0.975923  0.982343  0.982343
#
# model_number        79        80        81        82        83        84  \
# metric_type
# accuracy      0.995670  0.996336  0.997668  0.989674  0.991672  0.993338
# f1_score      0.989491  0.991122  0.994359  0.975020  0.979855  0.983819
# precision     0.996743  0.996753  0.998382  0.978964  0.983819  0.991843
# recall        0.982343  0.985554  0.990369  0.971108  0.975923  0.975923
#
# model_number        85        86        87        88        89        90  \
# metric_type
# accuracy      0.994670  0.995336  0.995670  0.997002  0.997668  0.989674
# f1_score      0.987076  0.988691  0.989508  0.992748  0.994359  0.975020
# precision     0.993496  0.995122  0.995130  0.996764  0.998382  0.978964
# recall        0.980738  0.982343  0.983949  0.988764  0.990369  0.971108
#
# model_number        91        92        93        94        95        96  \
# metric_type
# accuracy      0.991672  0.993338  0.994670  0.995336  0.996336  0.997668
# f1_score      0.979855  0.983819  0.987076  0.988691  0.991122  0.994350
# precision     0.983819  0.991843  0.993496  0.995122  0.996753  1.000000
# recall        0.975923  0.975923  0.980738  0.982343  0.985554  0.988764
#
# model_number        97  baseline_1  baseline_2
# metric_type
# accuracy      0.998001    0.792472    0.207528
# f1_score      0.995161    0.000000    0.343724
# precision     1.000000    0.000000    0.207528
# recall        0.990369    0.000000    1.000000

# %%
model_results
# Out:
#     model_number metric_type     score
# 0     baseline_1    accuracy  0.792472
# 1     baseline_1   precision  0.000000
# 2     baseline_1      recall  0.000000
# 3     baseline_1    f1_score  0.000000
# 4     baseline_2    accuracy  0.207528
# ..           ...         ...       ...
# 391           96    f1_score  0.994350
# 392           97    accuracy  0.998001
# 393           97   precision  1.000000
# 394           97      recall  0.990369
# 395           97    f1_score  0.995161
#
# [396 rows x 3 columns]

# %%
def get_best_model_results(model_results, metric_type='accuracy', n_models=4):
    '''
    This function takes in the model_results dataframe. This is a dataframe in tidy 
    data format containing the following data for each model created in the project:
    - model number
    - metric type (accuracy, precision, recall, f1 score)
    - sample type (train, validate)
    - score (the score for the given metric and sample types)

    The function identifies the {n_models} models with the highest scores for the given metric
    type, as measured on the validate sample.

    It returns a dataframe of information about those models' performance in the tidy data format
    (as described above). 

    The resulting dataframe can be fed into the display_model_results function for convenient display formatting.
    '''
    # create an array of model numbers for the best performing models
    # by filtering the model_results dataframe for only validate scores for the given metric type
    best_models = (model_results[(model_results.metric_type == metric_type)]                                                 # sort by score value in descending order
                                                 .sort_values(by='score', 
                                                              ascending=False)
                                                 # take only the model number for the top n_models
                                                 .head(n_models)
                                                 .model_number
                                                 # and take only the values from the resulting dataframe as an array
                                                 .values)
    # create a dataframe of model_results for the models identified above
    # by filtering the model_results dataframe for only the model_numbers in the best_models array
    # TODO: make this so that it will return n_models, rather than only 4 models
    best_model_results = model_results[(model_results.model_number == best_models[0]) 
                                     | (model_results.model_number == best_models[1]) 
                                     | (model_results.model_number == best_models[2])
                                     | (model_results.model_number == best_models[3])]

    return best_model_results

# %%
display_model_results(get_best_model_results(model_results, metric_type='recall')).T
# Out:
# metric_type   accuracy  f1_score  precision    recall
# model_number
# 24            0.999334  0.998395   0.998395  0.998395
# 25            0.999667  0.999197   1.000000  0.998395
# 33            0.998001  0.995169   0.998384  0.991974
# baseline_2    0.207528  0.343724   0.207528  1.000000

# %%
model_info[model_info.model_number.isin([24, 25, 33])]
# Out:
#    model_number     model_type  \
# 25           24  decision tree
# 26           25  decision tree
# 34           33  decision tree
#
#                                              features  max_depth
# 25  [originallistprice_scaled, scaled_livingarea, ...        9.0
# 26  [originallistprice_scaled, scaled_livingarea, ...       10.0
# 34  [originallistprice_scaled, scaled_livingarea, ...       10.0

# %% [markdown]
# ### Random Forest - RFE
